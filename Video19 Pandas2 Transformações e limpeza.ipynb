# %% [markdown]
# <a href="https://colab.research.google.com/github/fredericokrohling/1-Python-MBA/blob/main/Video19%20Pandas2%20Transforma%C3%A7%C3%B5es%20e%20limpeza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Transformacoes com APPLY, MAP e APPLYMAP
import pandas as pd
import numpy as np
dtips = pd.read_csv('tips.csv') # importar com o pandas cria automaticamente um DF

# %% [markdown]
# Apply - aplica uma funcao ao longo das linhas (axis =0)ou colunas (axis=1) de um DF
# MAP - aplica uma funcao em cada elemento de uma **Serie**
# Applymap - aplica uma funcao em cada elemento de um **DF**

# %%
dtips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       29.03  5.92    Male     No   Sat  Dinner     3
# 241       27.18   NaN  Female    Yes   Sat  Dinner     2
# 242       22.67   NaN    Male    Yes   Sat  Dinner     2
# 243       17.82  1.75    Male     No   Sat  Dinner     2
# 244         NaN  3.00  Female     No  Thur  Dinner     2
#
# [245 rows x 7 columns]

# %%
# Calular a soma das contas e gorgetas ao longo das linhas. Faz uma soma total
dtips[['total_bill','tip']].apply(np.sum)
# Out:
# total_bill    4817.15
# tip            727.43
# dtype: float64

# %%
# Calcular a soma da conta e gorgeta ao longo das colunas (total do dia)
# agrupando por dia e trazendo o resultado em uma coluna
dtips[['total_bill','tip']].apply(np.sum, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-842a5b185ab3> in <cell line: 3>()
#       1 # Calcular a soma da conta e gorgeta ao longo das colunas (total do dia)
#       2 # agrupando por dia e trazendo o resultado em uma coluna
# ----> 3 dtips[['total_bill','tip']].apply(np.sum, axis=1)
#
# NameError: name 'dtips' is not defined

# %%
# criando uma coluna com gorjeta media por pessoa na mesa
dtips['tip_perperson'] = dtips.apply(lambda x: np.round(x['tip']/x['size'],2), axis =1)
dtips

# nao entendi o x:
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_perperson
# 0         16.99  1.01  Female     No   Sun  Dinner     2           0.50
# 1         10.34  1.66    Male     No   Sun  Dinner     3           0.55
# 2         21.01  3.50    Male     No   Sun  Dinner     3           1.17
# 3         23.68  3.31    Male     No   Sun  Dinner     2           1.66
# 4         24.59  3.61  Female     No   Sun  Dinner     4           0.90
# ..          ...   ...     ...    ...   ...     ...   ...            ...
# 240       29.03  5.92    Male     No   Sat  Dinner     3           1.97
# 241       27.18   NaN  Female    Yes   Sat  Dinner     2            NaN
# 242       22.67   NaN    Male    Yes   Sat  Dinner     2            NaN
# 243       17.82  1.75    Male     No   Sat  Dinner     2           0.88
# 244         NaN  3.00  Female     No  Thur  Dinner     2           1.50
#
# [245 rows x 8 columns]

# %%
#Utilizando o Applymap - funciona em 2 colunas. Aplicado a um dataframe

dtips[['total_bill','tip']].applymap(np.round)
# Out:
# <ipython-input-13-129579e4124f>:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   dtips[['total_bill','tip']].applymap(np.round)
#      total_bill  tip
# 0          17.0  1.0
# 1          10.0  2.0
# 2          21.0  4.0
# 3          24.0  3.0
# 4          25.0  4.0
# ..          ...  ...
# 240        29.0  6.0
# 241        27.0  NaN
# 242        23.0  NaN
# 243        18.0  2.0
# 244         NaN  3.0
#
# [245 rows x 2 columns]

# %%
# Utilizando o MAP - Nao aceita ser aplicado para 2 colunas ao mesmo tempo

dtips['total_bill'].map(np.round)
# Out:
# 0      17.0
# 1      10.0
# 2      21.0
# 3      24.0
# 4      25.0
#        ...
# 240    29.0
# 241    27.0
# 242    23.0
# 243    18.0
# 244     NaN
# Name: total_bill, Length: 245, dtype: float64

# %% [markdown]
# LIMPEZA DE DADOS - TRATANDO COMO FALTANTES E DUPLICADOS

# %%
dtips = pd.read_csv('tips.csv') # importar com o pandas cria automaticamente um DF
pd.isna(dtips) # Verifica se existe um Not a number no DF

# Como verificar se existe entre as colunas 5 e 239, que nao estao sendo exibidas

np.any(pd.isna(dtips)) # retorna true se a consicao for verdadeira
# Out:
# True

# %%
# Percorrendo colunas - por padrao a iteracao eh por linhas, vamos fazer por colunas e procurar dados faltantes
#professor utilizou o metodo iteritems() mas foi removido do pandas, substitui por items()
import pandas as pd
print('Dados faltantes em:')
for (colName, colData) in dtips.items():
  if(np.any(pd.isna(colData))):
    print(colName)
# Out:
# Dados faltantes em:
# total_bill
# tip

# %%
# Verificando not a number nas colunas
np.any(dtips.isna(), axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 240    False
# 241     True
# 242     True
# 243    False
# 244     True
# Length: 245, dtype: bool

# %%
# para tentar achar os nan, podemos usar o loc
dtips.loc[np.any(dtips.isna(), axis=1)]
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 238       32.83  NaN    Male    Yes   Sat  Dinner     2
# 241       27.18  NaN  Female    Yes   Sat  Dinner     2
# 242       22.67  NaN    Male    Yes   Sat  Dinner     2
# 244         NaN  3.0  Female     No  Thur  Dinner     2

# %%
print(dtips.shape)
# Out:
# (245, 7)

# %%
# Comando dropna
# Remove as linhas e colunas onde dados faltantes existem
dtips_na_rows = dtips.dropna()
print(dtips_na_rows)
print(dtips_na_rows.shape)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 236       10.07  1.25    Male     No  Sat  Dinner     2
# 237       12.60  1.00    Male    Yes  Sat  Dinner     2
# 239       35.83  4.67  Female     No  Sat  Dinner     3
# 240       29.03  5.92    Male     No  Sat  Dinner     3
# 243       17.82  1.75    Male     No  Sat  Dinner     2
#
# [241 rows x 7 columns]
# (241, 7)

# %%
# Removendo as colunas onde tem NAN
dtips_na_rows = dtips.dropna(axis=1)
print(dtips_na_rows)
# Out:
#         sex smoker   day    time  size
# 0    Female     No   Sun  Dinner     2
# 1      Male     No   Sun  Dinner     3
# 2      Male     No   Sun  Dinner     3
# 3      Male     No   Sun  Dinner     2
# 4    Female     No   Sun  Dinner     4
# ..      ...    ...   ...     ...   ...
# 240    Male     No   Sat  Dinner     3
# 241  Female    Yes   Sat  Dinner     2
# 242    Male    Yes   Sat  Dinner     2
# 243    Male     No   Sat  Dinner     2
# 244  Female     No  Thur  Dinner     2
#
# [245 rows x 5 columns]

# %%
# Outra alternativa eh preencher o NAN com algum valor. Para isso utilizamos o comando fillna
dtips.loc[np.any(dtips.isna(), axis=1)]
dtips_fill1 = dtips.fillna(0) # onde tinha NAN estou preenchendo com zero
dtips_fill1.loc[np.any(dtips.isna(),axis=1)]
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 238       32.83  0.0    Male    Yes   Sat  Dinner     2
# 241       27.18  0.0  Female    Yes   Sat  Dinner     2
# 242       22.67  0.0    Male    Yes   Sat  Dinner     2
# 244        0.00  3.0  Female     No  Thur  Dinner     2

# %%
# realizando o preenchimento com dicionario

# crio o dicionario, vou querer preencher uma coluna com 10 e outra com 5
filldic = {'total_bill':10, 'tip':5}

#criando um novo DF e utilizando o fillna para preencher o DF com o dicionario criado
dtips_fill2 = dtips.fillna(filldic)

# Localizando se ha valores NA no DF
dtips_fill2.loc[np.any(dtips.isna(),axis=1)]
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 238       32.83  5.0    Male    Yes   Sat  Dinner     2
# 241       27.18  5.0  Female    Yes   Sat  Dinner     2
# 242       22.67  5.0    Male    Yes   Sat  Dinner     2
# 244       10.00  3.0  Female     No  Thur  Dinner     2

# %%
# Tratando linhas duplicadas - comando duplicated e drop_duplicates()
print(dtips.duplicated())
# nao vejo se ha algo entre o 5 e o 239, pois as linhas estao colapsadas
# para resolver isso

print('\n', dtips.duplicated().any())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# Length: 245, dtype: bool
#
#  True

# %%
# parametro KEEP
# False: retorna True para todas as duplicadas
# first: a primeira nao eh detectada
# last: a ultima nao eh detectada

dtips[dtips.duplicated(keep=False)]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 217        7.74  1.44  Male    Yes  Sat  Dinner     2
# 218        7.74  1.44  Male    Yes  Sat  Dinner     2
# 224       13.42  1.58  Male    Yes  Fri   Lunch     2
# 225       13.42  1.58  Male    Yes  Fri   Lunch     2

# %%
# mostrando as segundas linhas duplicadas
dtips[dtips.duplicated(keep='first')]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 218        7.74  1.44  Male    Yes  Sat  Dinner     2
# 225       13.42  1.58  Male    Yes  Fri   Lunch     2

# %%
# removendo as duplicadas com o drop duplicates
dtips_first = dtips.drop_duplicates(keep='first')
print(dtips_first.iloc[216:225])
# veja que as linhas 218 e 225 foram removidas
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 216       11.59  1.50    Male    Yes  Sat  Dinner     2
# 217        7.74  1.44    Male    Yes  Sat  Dinner     2
# 219       30.14  3.09  Female    Yes  Sat  Dinner     4
# 220       12.16  2.20    Male    Yes  Fri   Lunch     2
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 222        8.58  1.92    Male    Yes  Fri   Lunch     1
# 223       15.98  3.00  Female     No  Fri   Lunch     3
# 224       13.42  1.58    Male    Yes  Fri   Lunch     2
# 226       16.27  2.50  Female    Yes  Fri   Lunch     2

# %%
# Apos a remocao, resete os indices para ajustar os dados
dtips_first = dtips_first.reset_index()
#verificando
print(dtips_first.iloc[216:225])
# Out:
#      level_0  index  total_bill   tip     sex smoker  day    time  size
# 216      216    216       11.59  1.50    Male    Yes  Sat  Dinner     2
# 217      217    217        7.74  1.44    Male    Yes  Sat  Dinner     2
# 218      218    219       30.14  3.09  Female    Yes  Sat  Dinner     4
# 219      219    220       12.16  2.20    Male    Yes  Fri   Lunch     2
# 220      220    221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 221      221    222        8.58  1.92    Male    Yes  Fri   Lunch     1
# 222      222    223       15.98  3.00  Female     No  Fri   Lunch     3
# 223      223    224       13.42  1.58    Male    Yes  Fri   Lunch     2
# 224      224    226       16.27  2.50  Female    Yes  Fri   Lunch     2
